# %%
from mistralai.client import Mistral

api_key = "sTtbKxZpJ6xkk1TYPpC2I4Qej8nfhhaanasdnDdJfxPzrC"

client = Mistral(api_key=api_key)

def chat_with_ai(prompt):
    response = client.chat.complete(
        model="mistral-small-latest",
        messages=[
            {"role": "user", "content": prompt}
        ]
    )
    return response.choices[0].message.content


def main():
    print("AI Assistant (Mistral) (type 'exit' to quit)\n")

    while True:
        user_input = input("You: ")

        if user_input.lower() == "exit":
            print("Goodbye!")
            break

        reply = chat_with_ai(user_input)
        print("AI:", reply, "\n")


if __name__ == "__main__":
    main()
# Out:
# AI Assistant (Mistral) (type 'exit' to quit)
#
# You: what is the colour of apple?
# AI: The color of an apple can vary depending on the variety. Common colors include:
#
# - **Red** (e.g., Red Delicious, Fuji)
# - **Green** (e.g., Granny Smith)
# - **Yellow** (e.g., Golden Delicious)
# - **Pink/Reddish** (e.g., Pink Lady)
# - **Purple/Black** (e.g., Black Diamond)
#
# Some apples may also have a mix of colors, like red with yellow or green streaks. The color often indicates ripeness and sweetness—red apples tend to be sweeter, while green ones are usually tarter.
#
# Would you like to know about a specific variety? 😊🍏🍎
#
# You: exit
# Goodbye!
